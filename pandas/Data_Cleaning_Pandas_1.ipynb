# %% [markdown]
# # Data Cleaning Using Pandas:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("results.csv")
data
# Out:
#       Unnamed: 0 Result     Margin   BR  Toss  Bat   Opposition      Ground  \
# 0            418    won    85 runs  NaN  lost  1st      v India     Kolkata
# 1            692   lost    85 runs  NaN   won  2nd   v Pakistan     Kolkata
# 2            419   lost    10 runs  NaN  lost  2nd      v India       Delhi
# 3            693    won    10 runs  NaN   won  1st   v Pakistan       Delhi
# 4            121   lost   107 runs  NaN  lost  2nd  v Australia   Melbourne
# ...          ...    ...        ...  ...   ...  ...          ...         ...
# 1317         997    won  3 wickets  3.0   won  2nd   v Pakistan  Nottingham
# 1318         282   aban          -  NaN     -    -   v Scotland   Edinburgh
# 1319        1322      -          -  NaN   won  2nd    v Ireland     Belfast
# 1320         559      -          -  NaN  lost  2nd    v England       Leeds
# 1321         998      -          -  NaN   won  1st   v Pakistan       Leeds
#
#        Start Date     Match_ID      Country  Country_ID
# 0      3 Jan 2013   ODI # 3315     Pakistan           7
# 1      3 Jan 2013   ODI # 3315        India           6
# 2      6 Jan 2013   ODI # 3316     Pakistan           7
# 3      6 Jan 2013   ODI # 3316        India           6
# 4     11 Jan 2013   ODI # 3317     SriLanka           8
# ...           ...          ...          ...         ...
# 1317  17 May 2019   ODI # 4138      England           1
# 1318  18 May 2019  ODI # 4138a     SriLanka           8
# 1319  19 May 2019   ODI # 4139  Afghanistan          40
# 1320  19 May 2019   ODI # 4140     Pakistan           7
# 1321  19 May 2019   ODI # 4140      England           1
#
# [1322 rows x 12 columns]

# %% [markdown]
# ## DATA CLEANING & DATA TRANSFORMATION:

# %% [markdown]
# ### DATA CLEANING:
# ```Data cleaning is the process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset.```<br>
# ```There is no one absolute way to prescribe the exact steps in the data cleaning process because the processes will vary from dataset to dataset.```<br>
# ### DATA TRANSFORMATION:
# ```Data transformation is the process of converting data from one format or structure into another.```<br>
# ```Transformation processes can also be referred to as data wrangling, or data munging, transforming and mapping data from one "raw" data form into another format for warehousing and analyzing.```

# %% [markdown]
# #### Mostly there are three types of Errors in datasets:
# #### - Missing Values
# #### - Duplicate Values
# #### - Bad Values (outliers)

# %% [markdown]
# ### Data Type and Conversions:
# There are 7 data types:-<br>
# - __object__ This data type is used for strings<br>
# - __int64__ Used for integers<br>
# - __float64__ Used for floating-point numbers<br>
# - __bool__ Used for values that can only be True/False<br>
# - __datetime64__ Used for date and time values<br>
# - __timedelta__ Used to represent the difference between datetimes<br>
# - __category__ a pandas data type corresponding to categorical variables in statistics<br>

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Result         object
# Margin         object
# BR            float64
# Toss           object
# Bat            object
# Opposition     object
# Ground         object
# Start Date     object
# Match_ID       object
# Country        object
# Country_ID      int64
# dtype: object

# %% [markdown]
# ### Converting data types:
# #### There are two standard ways of converting pandas data types:
# - __astype()__
# - __pd.to_datetime__ etc

# %%
data['Result'] = data['Result'].astype('category')
data['Toss'] = data['Toss'].astype('category')
data['Bat'] = data['Bat'].astype('category')
data['Start Date'] = pd.to_datetime(data['Start Date'])
data.dtypes
# Out:
# Unnamed: 0             int64
# Result              category
# Margin                object
# BR                   float64
# Toss                category
# Bat                 category
# Opposition            object
# Ground                object
# Start Date    datetime64[ns]
# Match_ID              object
# Country               object
# Country_ID             int64
# dtype: object

# %%
data.select_dtypes(include='category').head()
# Out:
#   Result  Toss  Bat
# 0    won  lost  1st
# 1   lost   won  2nd
# 2   lost  lost  2nd
# 3    won   won  1st
# 4   lost  lost  2nd

# %%
data2 = pd.read_csv('train.csv')
data2.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %%
data2.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
print(data2['LotFrontage'].isna().sum())
print(data2['LotFrontage'].mean())
print(data2['LotFrontage'].median())
print(data2['LotFrontage'].mode())
# Out:
# 259
# 70.04995836802665
# 69.0
# 0    60.0
# Name: LotFrontage, dtype: float64

# %%
data['BR'].interpolate().plot

# %% [markdown]
# ## 1)Handling with missing data

# %% [markdown]
# when we are handling missing data we use following pandas functions:<br>
# - __isna()__
# - __notna()__

# %% [markdown]
# #### Inserting missing data:

# %%
df = pd.DataFrame({"A":[12, 4, 5, None, 1],
                   "B":[None, 2, 54, 3, None],
                   "C":[20, 16, None, 3, 8],
                   "D":[14, 3, None, None, 6]})
df
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
df.iloc[3,0]= 12
df
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3  12.0   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %% [markdown]
# ### Calculations with missing data:

# %%
df1 = pd.DataFrame({"A":[12, 4, 5, None, 1],
                   "B":[None, 2, 54, 3, None],
                   "C":[20, 16, None, 3, 8],
                   "D":[14, 3, None, None, 6]})
df2 = pd.DataFrame({"A":[None, 4, 5, 7, 1],
                   "B":[8, 2, None, 3, 7],
                   "C":[None, 16, None, 3, 8],
                   "D":[14, 3, 2, 8, None]})

# %%
df1+df2
# Out:
#       A    B     C     D
# 0   NaN  NaN   NaN  28.0
# 1   8.0  4.0  32.0   6.0
# 2  10.0  NaN   NaN   NaN
# 3   NaN  6.0   6.0   NaN
# 4   2.0  NaN  16.0   NaN

# %% [markdown]
# #### Summary From Above Result:
# - When summing data, NA (missing) values will be treated as zero.
#
# - If the data are all NA, the result will be 0.
#
# - Cumulative methods like cumsum() and cumprod() ignore NA values by default,

# %% [markdown]
# ### Sum/prod of empties/nans:

# %%
pd.Series([np.nan]).sum()
# Out:
# 0.0

# %%
pd.Series([np.nan]).prod()
# Out:
# 1.0

# %% [markdown]
# ### NA values in GroupBy:
# NA groups in GroupBy are automatically excluded.

# %%
df1
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0

# %%
df.groupby("A").sum()
# Out:
#          B     C     D
# A
# 1.0    0.0   8.0   6.0
# 4.0    2.0  16.0   3.0
# 5.0   54.0   0.0   0.0
# 12.0   3.0  23.0  14.0

# %% [markdown]
# ### Cleaning / filling missing data:
# - __fillna()__

# %%
df1['A'].fillna("missing",inplace=False)
df1
# Out:
#          A     B     C     D
# 0     12.0   NaN  20.0  14.0
# 1      4.0   2.0  16.0   3.0
# 2      5.0  54.0   NaN   NaN
# 3  missing   3.0   3.0   NaN
# 4      1.0   NaN   8.0   6.0

# %% [markdown]
# #### Fill gaps forward or backward:
# - __pad / ffill__ Fill values forward<br>
# - __bfill / backfill__ Fill values backward<br>

# %%
df1['B'].fillna(method="ffill",inplace= True)
df1
# Out:
#          A     B     C     D
# 0     12.0   NaN  20.0  14.0
# 1      4.0   2.0  16.0   3.0
# 2      5.0  54.0   NaN   NaN
# 3  missing   3.0   3.0   NaN
# 4      1.0   3.0   8.0   6.0

# %%
df1['C'].fillna(method="bfill",inplace= True)
df1
# Out:
#          A     B     C     D
# 0     12.0   NaN  20.0  14.0
# 1      4.0   2.0  16.0   3.0
# 2      5.0  54.0   3.0   NaN
# 3  missing   3.0   3.0   NaN
# 4      1.0   3.0   8.0   6.0

# %%
df3 = pd.DataFrame(np.random.randn(10,4),columns=list("ABCD"))
df3.iloc[3:5,0]=np.nan
df3.iloc[2:7,1]=np.nan
df3.iloc[3:6,2]=np.nan
df3.iloc[5:7,3]=np.nan
df3
# Out:
#           A         B         C         D
# 0  0.876684 -2.823976  2.229619  0.428361
# 1  0.861203 -1.058308  0.525564 -0.192306
# 2 -0.160296       NaN  0.092535 -0.421620
# 3       NaN       NaN       NaN  0.362726
# 4       NaN       NaN       NaN -0.070391
# 5 -0.699207       NaN       NaN       NaN
# 6  0.170948       NaN -1.287744       NaN
# 7 -0.151854 -0.133488  0.565547 -1.004980
# 8  0.927645 -1.139070  0.151511  0.307222
# 9 -0.228319 -0.581477 -1.741595  0.475769

# %%
df3.fillna(df3.mean())
# Out:
#           A         B         C         D
# 0 -0.425501  1.719691  1.824495  0.943210
# 1 -0.425501  1.432555  0.182683 -0.516908
# 2 -0.425501  0.805395 -0.273470 -0.866168
# 3 -0.425501  0.805395  0.548740  0.433174
# 4 -0.425501  0.805395  0.548740  1.122743
# 5  0.169823  0.805395  0.548740  0.125032
# 6 -0.945244  0.805395 -0.840267  0.125032
# 7 -0.676381 -0.309364  2.756764 -1.113173
# 8 -1.345713  0.060252 -1.057778  1.112753
# 9  0.670012  1.123842  1.248755 -0.115378

# %%
df3.fillna(df3.mean()["B":"C"])
# Out:
#           A         B         C         D
# 0       NaN  1.719691  1.824495  0.943210
# 1       NaN  1.432555  0.182683 -0.516908
# 2       NaN  0.805395 -0.273470 -0.866168
# 3       NaN  0.805395  0.548740  0.433174
# 4       NaN  0.805395  0.548740  1.122743
# 5  0.169823  0.805395  0.548740       NaN
# 6 -0.945244  0.805395 -0.840267       NaN
# 7 -0.676381 -0.309364  2.756764 -1.113173
# 8 -1.345713  0.060252 -1.057778  1.112753
# 9  0.670012  1.123842  1.248755 -0.115378

# %%
df3.where(pd.notna(df3), df3.mean(), axis="columns")
# Out:
#           A         B         C         D
# 0 -0.425501  1.719691  1.824495  0.943210
# 1 -0.425501  1.432555  0.182683 -0.516908
# 2 -0.425501  0.805395 -0.273470 -0.866168
# 3 -0.425501  0.805395  0.548740  0.433174
# 4 -0.425501  0.805395  0.548740  1.122743
# 5  0.169823  0.805395  0.548740  0.125032
# 6 -0.945244  0.805395 -0.840267  0.125032
# 7 -0.676381 -0.309364  2.756764 -1.113173
# 8 -1.345713  0.060252 -1.057778  1.112753
# 9  0.670012  1.123842  1.248755 -0.115378

# %%
df3.dropna(axis=0)
# Out:
#           A         B         C         D
# 7 -0.676381 -0.309364  2.756764 -1.113173
# 8 -1.345713  0.060252 -1.057778  1.112753
# 9  0.670012  1.123842  1.248755 -0.115378

# %% [markdown]
# ### Interpolation
# Both Series and DataFrame objects have interpolate() that, by default, performs linear interpolation at missing data points.
# ### Interpolation methods:
# - __linear__
# - __quadratic__
# - __pchip__
# - __akima__
# ### Interpolation methods:

# %%
df3.interpolate()
# Out:
#           A         B         C         D
# 0  0.876684 -2.823976  2.229619  0.428361
# 1  0.861203 -1.058308  0.525564 -0.192306
# 2 -0.160296 -0.904171  0.092535 -0.421620
# 3 -0.339933 -0.750034 -0.252535  0.362726
# 4 -0.519570 -0.595898 -0.597605 -0.070391
# 5 -0.699207 -0.441761 -0.942674 -0.381920
# 6  0.170948 -0.287624 -1.287744 -0.693450
# 7 -0.151854 -0.133488  0.565547 -1.004980
# 8  0.927645 -1.139070  0.151511  0.307222
# 9 -0.228319 -0.581477 -1.741595  0.475769

# %%
df3['A'].interpolate()
# Out:
# 0    0.876684
# 1    0.861203
# 2   -0.160296
# 3   -0.339933
# 4   -0.519570
# 5   -0.699207
# 6    0.170948
# 7   -0.151854
# 8    0.927645
# 9   -0.228319
# Name: A, dtype: float64

# %%
df3.interpolate(method="quadratic")
# Out:
#           A         B         C         D
# 0  0.876684 -2.823976  2.229619  0.428361
# 1  0.861203 -1.058308  0.525564 -0.192306
# 2 -0.160296  0.228451  0.092535 -0.421620
# 3 -0.920970  1.036301 -0.547747  0.362726
# 4 -1.173322  1.365243 -1.641662 -0.070391
# 5 -0.699207  1.258375 -2.213549 -0.798194
# 6  0.170948  0.758798 -1.287744 -1.432370
# 7 -0.151854 -0.133488  0.565547 -1.004980
# 8  0.927645 -1.139070  0.151511  0.307222
# 9 -0.228319 -0.581477 -1.741595  0.475769

# %%
df3.interpolate(method="pchip")
# Out:
#           A         B         C         D
# 0  0.876684 -2.823976  2.229619  0.428361
# 1  0.861203 -1.058308  0.525564 -0.192306
# 2 -0.160296 -0.743731  0.092535 -0.421620
# 3 -0.453771 -0.503568 -0.344175  0.362726
# 4 -0.636368 -0.330140 -0.794086 -0.070391
# 5 -0.699207 -0.215770 -1.145756 -0.478263
# 6  0.170948 -0.152778 -1.287744 -0.845464
# 7 -0.151854 -0.133488  0.565547 -1.004980
# 8  0.927645 -1.139070  0.151511  0.307222
# 9 -0.228319 -0.581477 -1.741595  0.475769

# %%
df3.interpolate(method="akima")
# Out:
#           A         B         C         D
# 0  0.876684 -2.823976  2.229619  0.428361
# 1  0.861203 -1.058308  0.525564 -0.192306
# 2 -0.160296 -0.354077  0.092535 -0.421620
# 3 -0.627514  0.111071 -0.299279  0.362726
# 4 -0.808137  0.351419 -0.666522 -0.070391
# 5 -0.699207  0.381253 -0.999305 -0.447478
# 6  0.170948  0.214856 -1.287744 -0.778241
# 7 -0.151854 -0.133488  0.565547 -1.004980
# 8  0.927645 -1.139070  0.151511  0.307222
# 9 -0.228319 -0.581477 -1.741595  0.475769

# %% [markdown]
# ### Replacing generic values:

# %%
df3.replace(df3.mean())
# Out:
#           A         B         C         D
# 0  0.876684 -2.823976  2.229619  0.428361
# 1  0.861203 -1.058308  0.525564 -0.192306
# 2 -0.160296       NaN  0.092535 -0.421620
# 3       NaN       NaN       NaN  0.362726
# 4       NaN       NaN       NaN -0.070391
# 5 -0.699207       NaN       NaN       NaN
# 6  0.170948       NaN -1.287744       NaN
# 7 -0.151854 -0.133488  0.565547 -1.004980
# 8  0.927645 -1.139070  0.151511  0.307222
# 9 -0.228319 -0.581477 -1.741595  0.475769

# %% [markdown]
# ## 2)Duplicates

# %%
df = pd.DataFrame({
    "A":[12,22,32,42,52],
    "B":[11,12,13,14,15],
    "C":[1,2,3,4,5],
    "C":[13,23,33,34,53],
},
index=["a","a","b","c","d"],
columns=["A","B","C","C"]    
)
df
# Out:
#     A   B   C   C
# a  12  11  13  13
# a  22  12  23  23
# b  32  13  33  33
# c  42  14  34  34
# d  52  15  53  53

# %%
df.reindex(["a","b","c","d","e"])# reindex method doesn't work on duplicate values
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_13252\1152341668.py:1: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   df.reindex(["a","b","c","d","e"])# reindex method doesn't work on duplicate values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [130], in <cell line: 1>()
# ----> 1 df.reindex(["a","b","c","d","e"])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:324, in rewrite_axis_style_signature.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     322 @wraps(func)
#     323 def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324     return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4804, in DataFrame.reindex(self, *args, **kwargs)
#    4802 kwargs.pop("axis", None)
#    4803 kwargs.pop("labels", None)
# -> 4804 return super().reindex(**kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4966, in NDFrame.reindex(self, *args, **kwargs)
#    4963     return self._reindex_multi(axes, copy, fill_value)
#    4965 # perform the reindex on the axes
# -> 4966 return self._reindex_axes(
#    4967     axes, level, limit, tolerance, method, fill_value, copy
#    4968 ).__finalize__(self, method="reindex")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4623, in DataFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4621 index = axes["index"]
#    4622 if index is not None:
# -> 4623     frame = frame._reindex_index(
#    4624         index, method, copy, level, fill_value, limit, tolerance
#    4625     )
#    4627 return frame
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4642, in DataFrame._reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    4629 def _reindex_index(
#    4630     self,
#    4631     new_index,
#    (...)
#    4637     tolerance=None,
#    4638 ):
#    4639     new_index, indexer = self.index.reindex(
#    4640         new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    4641     )
# -> 4642     return self._reindex_with_indexers(
#    4643         {0: [new_index, indexer]},
#    4644         copy=copy,
#    4645         fill_value=fill_value,
#    4646         allow_dups=False,
#    4647     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5032, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5029     indexer = ensure_platform_int(indexer)
#    5031 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032 new_data = new_data.reindex_indexer(
#    5033     index,
#    5034     indexer,
#    5035     axis=baxis,
#    5036     fill_value=fill_value,
#    5037     allow_dups=allow_dups,
#    5038     copy=copy,
#    5039 )
#    5040 # If we've made a copy once, no need to make another one
#    5041 copy = False
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:679, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
# --> 679     self.axes[axis]._validate_can_reindex(indexer)
#     681 if axis >= self.ndim:
#     682     raise IndexError("Requested axis not found in manager")
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4107, in Index._validate_can_reindex(self, indexer)
#    4105 # trying to reindex on an axis with duplicates
#    4106 if not self._index_as_unique and len(indexer):
# -> 4107     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
print(df['A']) 
print(df['C'])# this makes difficulty which C series yu call?
# Out:
# a    12
# a    22
# b    32
# c    42
# d    52
# Name: A, dtype: int64
#     C   C
# a  13  13
# a  23  23
# b  33  33
# c  34  34
# d  53  53

# %%
df.loc['a','A']# this also makes difficulty which value of a?
# Out:
# a    12
# a    22
# Name: A, dtype: int64

# %%
df.index.duplicated()
# Out:
# array([False,  True, False, False, False])

# %%
df.loc[~df2.index.duplicated(), :]
# Out:
#     A   B   C   C
# a  12  11  13  13
# a  22  12  23  23
# b  32  13  33  33
# c  42  14  34  34
# d  52  15  53  53

# %%
df.groupby(level=0).mean()
# Out:
#       A     B     C     C
# a  17.0  11.5  18.0  18.0
# b  32.0  13.0  33.0  33.0
# c  42.0  14.0  34.0  34.0
# d  52.0  15.0  53.0  53.0

# %% [markdown]
# #### Disallowing Duplicate Labels:

# %%
df.set_flags(allows_duplicate_labels=False)
# Out:
# ---------------------------------------------------------------------------
# DuplicateLabelError                       Traceback (most recent call last)
# Input In [142], in <cell line: 1>()
# ----> 1 df.set_flags(allows_duplicate_labels=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:438, in NDFrame.set_flags(self, copy, allows_duplicate_labels)
#     436 df = self.copy(deep=copy)
#     437 if allows_duplicate_labels is not None:
# --> 438     df.flags["allows_duplicate_labels"] = allows_duplicate_labels
#     439 return df
#
# File ~\anaconda3\lib\site-packages\pandas\core\flags.py:105, in Flags.__setitem__(self, key, value)
#     103 if key not in self._keys:
#     104     raise ValueError(f"Unknown flag {key}. Must be one of {self._keys}")
# --> 105 setattr(self, key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\flags.py:92, in Flags.allows_duplicate_labels(self, value)
#      90 if not value:
#      91     for ax in obj.axes:
# ---> 92         ax._maybe_check_unique()
#      94 self._allows_duplicate_labels = value
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:715, in Index._maybe_check_unique(self)
#     712 duplicates = self._format_duplicate_message()
#     713 msg += f"\n{duplicates}"
# --> 715 raise DuplicateLabelError(msg)
#
# DuplicateLabelError: Index has duplicates.
#       positions
# label
# a        [0, 1]

# %%
df.flags.allows_duplicate_labels
# Out:
# True

# %%
df2 = df.set_flags(allows_duplicate_labels=False)
df2
# Out:
# ---------------------------------------------------------------------------
# DuplicateLabelError                       Traceback (most recent call last)
# Input In [145], in <cell line: 1>()
# ----> 1 df2 = df.set_flags(allows_duplicate_labels=False)
#       2 df2
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:438, in NDFrame.set_flags(self, copy, allows_duplicate_labels)
#     436 df = self.copy(deep=copy)
#     437 if allows_duplicate_labels is not None:
# --> 438     df.flags["allows_duplicate_labels"] = allows_duplicate_labels
#     439 return df
#
# File ~\anaconda3\lib\site-packages\pandas\core\flags.py:105, in Flags.__setitem__(self, key, value)
#     103 if key not in self._keys:
#     104     raise ValueError(f"Unknown flag {key}. Must be one of {self._keys}")
# --> 105 setattr(self, key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\flags.py:92, in Flags.allows_duplicate_labels(self, value)
#      90 if not value:
#      91     for ax in obj.axes:
# ---> 92         ax._maybe_check_unique()
#      94 self._allows_duplicate_labels = value
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:715, in Index._maybe_check_unique(self)
#     712 duplicates = self._format_duplicate_message()
#     713 msg += f"\n{duplicates}"
# --> 715 raise DuplicateLabelError(msg)
#
# DuplicateLabelError: Index has duplicates.
#       positions
# label
# a        [0, 1]

# %%
df.groupby(level=0).first() # disallow first a row duplication
# Out:
#     A   B   C   C
# a  12  11  13  13
# b  32  13  33  33
# c  42  14  34  34
# d  52  15  53  53

# %%
# Out:
#     A   B   C   C
# a  12  11  13  13
# a  22  12  23  23
# b  32  13  33  33
# c  42  14  34  34
# d  52  15  53  53
